# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from glob import glob
import seaborn as sns
from PIL import Image
np.random.seed(42)
from sklearn.metrics import confusion_matrix
import keras
from keras.utils.np_utils import to_categorical # used for converting labels to one-hot-encoding
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization
from sklearn.model_selection import train_test_split
from scipy import stats
from sklearn.preprocessing import LabelEncoder

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cancer_data=pd.read_csv('/content/gdrive/MyDrive/data/HAM10000/HAM10000_metadata.csv',sep=',',header=0)
cancer_data.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
cancer_data.shape
# Out:
# (10015, 7)

# %%
size =32

# %%
le = LabelEncoder()
le.fit(cancer_data['dx'])
LabelEncoder()
print(list(le.classes_))
# Out:
# ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']

# %%
cancer_data['label']=le.transform(cancer_data['dx'])
print(cancer_data.sample(10))
# Out:
#         lesion_id      image_id   dx  ...     sex     localization label
# 1617  HAM_0007180  ISIC_0033272  mel  ...    male             face     4
# 8128  HAM_0007195  ISIC_0031923   nv  ...  female  lower extremity     5
# 2168  HAM_0001835  ISIC_0026652  mel  ...    male             back     4
# 1090  HAM_0000465  ISIC_0030583  bkl  ...  female            trunk     2
# 7754  HAM_0001720  ISIC_0034010   nv  ...    male          abdomen     5
# 8071  HAM_0006333  ISIC_0024424   nv  ...    male            trunk     5
# 7423  HAM_0004548  ISIC_0032832   nv  ...  female  upper extremity     5
# 8984  HAM_0006526  ISIC_0026671   nv  ...    male  lower extremity     5
# 2310  HAM_0003102  ISIC_0032389  mel  ...    male             face     4
# 7256  HAM_0004260  ISIC_0025525   nv  ...    male             back     5
#
# [10 rows x 8 columns]

# %%
cancer_data.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  label
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp      2
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp      2
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp      2
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp      2
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear      2

# %%
cancer_data.shape
# Out:
# (10015, 8)

# %%
fig = plt.figure(figsize=(12,8))

ax1 = fig.add_subplot(221)
cancer_data['dx'].value_counts().plot(kind='bar', ax=ax1)
ax1.set_ylabel('Count')
ax1.set_title('Cell Type');

ax2 = fig.add_subplot(222)
cancer_data['sex'].value_counts().plot(kind='bar', ax=ax2)
ax2.set_ylabel('Count', size=15)
ax2.set_title('Sex');

ax3 = fig.add_subplot(223)
cancer_data['localization'].value_counts().plot(kind='bar')
ax3.set_ylabel('Count',size=12)
ax3.set_title('Localization')

ax4 = fig.add_subplot(224)
sample_age = cancer_data[pd.notnull(cancer_data['age'])]
sns.distplot(sample_age['age'], fit=stats.norm, color='red');
ax4.set_title('Age')

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn.utils import resample

# %%
print(cancer_data['label'].value_counts())
# Out:
# 5    6705
# 4    1113
# 2    1099
# 1     514
# 0     327
# 6     142
# 3     115
# Name: label, dtype: int64

# %%
df_0 = cancer_data[cancer_data['label']==0]
df_1 = cancer_data[cancer_data['label']==1]
df_2 = cancer_data[cancer_data['label']==2]
df_3 = cancer_data[cancer_data['label']==3]
df_4 = cancer_data[cancer_data['label']==4]
df_5 = cancer_data[cancer_data['label']==5]
df_6 = cancer_data[cancer_data['label']==6]

# %%
df_0.shape
# Out:
# (327, 8)

# %%
n_samples = 500

# %%
df_0_balanced = resample(df_0, replace=True, n_samples=n_samples, random_state=42) 
df_1_balanced = resample(df_1, replace=True, n_samples=n_samples, random_state=42) 
df_2_balanced = resample(df_2, replace=True, n_samples=n_samples, random_state=42)
df_3_balanced = resample(df_3, replace=True, n_samples=n_samples, random_state=42)
df_4_balanced = resample(df_4, replace=True, n_samples=n_samples, random_state=42)
df_5_balanced = resample(df_5, replace=True, n_samples=n_samples, random_state=42)
df_6_balanced = resample(df_6, replace=True, n_samples=n_samples, random_state=42)

# %%
data_cancer_balanced = pd.concat([df_0_balanced,df_1_balanced,df_2_balanced,
                                  df_3_balanced,df_4_balanced,df_5_balanced,
                                  df_6_balanced])

# %%
data_cancer_balanced.shape
# Out:
# (3500, 8)

# %%
print(data_cancer_balanced['label'].value_counts())
# Out:
# 5    500
# 3    500
# 1    500
# 6    500
# 4    500
# 2    500
# 0    500
# Name: label, dtype: int64

# %%
data_cancer_balanced.shape
# Out:
# (3500, 8)

# %%
images_path = {os.path.splitext(os.path.basename(x))[0]: x
               for x in glob(os.path.join('/content/gdrive/MyDrive/data/HAM10000/','*','*.jpg'))}

# %%
print(images_path)

# %%
data_cancer_balanced['path'] = cancer_data['image_id'].map(images_path.get)

# %%
data_cancer_balanced.head()
# Out:
#         lesion_id  ...                                               path
# 9789  HAM_0003136  ...  /content/gdrive/MyDrive/data/HAM10000/HAM10000...
# 9957  HAM_0006587  ...  /content/gdrive/MyDrive/data/HAM10000/HAM10000...
# 9793  HAM_0005505  ...  /content/gdrive/MyDrive/data/HAM10000/HAM10000...
# 9758  HAM_0003455  ...  /content/gdrive/MyDrive/data/HAM10000/HAM10000...
# 9875  HAM_0005459  ...  /content/gdrive/MyDrive/data/HAM10000/HAM10000...
#
# [5 rows x 9 columns]

# %%
data_cancer_balanced['image'] = data_cancer_balanced['path'].map(lambda x: np.asarray(Image.open(x).resize((size,size))))
#data_cancer_balanced['image'] = data_cancer_balanced['path'].map(lambda x: np.asarray(Image.open(x).resize((SIZE,SIZE))))

# %%
data_cancer_balanced.head()
# Out:
#         lesion_id  ...                                              image
# 9789  HAM_0003136  ...  [[[155, 118, 107], [162, 126, 118], [174, 140,...
# 9957  HAM_0006587  ...  [[[138, 76, 82], [131, 64, 68], [139, 73, 81],...
# 9793  HAM_0005505  ...  [[[123, 86, 87], [174, 137, 137], [197, 161, 1...
# 9758  HAM_0003455  ...  [[[205, 149, 175], [207, 149, 169], [214, 158,...
# 9875  HAM_0005459  ...  [[[203, 174, 199], [205, 174, 197], [206, 175,...
#
# [5 rows x 10 columns]

# %% [markdown]
# #Plotting images

# %%
n_images = 5 # number of images plotting

# %%
fig, m_axs = plt.subplots(7, n_images, figsize = (4*n_images, 3*7))
for n_axs, (type_name, type_rows) in zip(m_axs, 
                                         data_cancer_balanced.sort_values(['dx']).groupby('dx')):
    n_axs[0].set_title(type_name)
    for c_ax, (_, c_row) in zip(n_axs, type_rows.sample(n_images, random_state=1234).iterrows()):
        c_ax.imshow(c_row['image'])
        c_ax.axis('off')

# %% [markdown]
# #split training & testing

# %%
X = np.asarray(data_cancer_balanced['image'].tolist())

# %%
X = X/255.

# %%
X.shape
# Out:
# (3500, 32, 32, 3)

# %%
Y = data_cancer_balanced['label']

# %%
Y_cat = to_categorical(Y,num_classes = 7)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y_cat, test_size=0.1, random_state=42)

# %% [markdown]
# #Model

# %%
num_classes = 7

# %%
model = Sequential()
model.add(Conv2D(256, (3, 3), activation="relu", input_shape=(size, size, 3)))
#model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))  
model.add(Dropout(0.3))

model.add(Conv2D(128, (3, 3),activation='relu'))
#model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))  
model.add(Dropout(0.3))

model.add(Conv2D(64, (3, 3),activation='relu'))
#model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))  
model.add(Dropout(0.3))
model.add(Flatten())

model.add(Dense(32))
model.add(Dense(7, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 256)       7168
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 256)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 15, 256)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 128)       295040
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          73792
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                8224
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 231
# =================================================================
# Total params: 384,455
# Trainable params: 384,455
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
batch_size = 16 
epochs = 50

# %%
history = model.fit(x_train, y_train,epochs=epochs,batch_size = batch_size,validation_data=(x_test, y_test),verbose=1)
# Out:
# Epoch 1/50
# 197/197 [==============================] - 46s 9ms/step - loss: 1.9431 - accuracy: 0.1576 - val_loss: 1.8030 - val_accuracy: 0.2543
# Epoch 2/50
# 197/197 [==============================] - 1s 6ms/step - loss: 1.7087 - accuracy: 0.3009 - val_loss: 1.4871 - val_accuracy: 0.3857
# Epoch 3/50
# 197/197 [==============================] - 1s 5ms/step - loss: 1.4897 - accuracy: 0.3932 - val_loss: 1.4591 - val_accuracy: 0.3886
# Epoch 4/50
# 197/197 [==============================] - 1s 5ms/step - loss: 1.4538 - accuracy: 0.4081 - val_loss: 1.3273 - val_accuracy: 0.5229
# Epoch 5/50
# 197/197 [==============================] - 1s 5ms/step - loss: 1.3488 - accuracy: 0.4715 - val_loss: 1.3180 - val_accuracy: 0.4514
# Epoch 6/50
# 197/197 [==============================] - 1s 5ms/step - loss: 1.3553 - accuracy: 0.4682 - val_loss: 1.2802 - val_accuracy: 0.5114
# Epoch 7/50
# 197/197 [==============================] - 1s 5ms/step - loss: 1.2997 - accuracy: 0.4984 - val_loss: 1.3195 - val_accuracy: 0.4400
# Epoch 8/50
# 197/197 [==============================] - 1s 5ms/step - loss: 1.2585 - accuracy: 0.5038 - val_loss: 1.2212 - val_accuracy: 0.5057
# Epoch 9/50
# 197/197 [==============================] - 1s 5ms/step - loss: 1.2459 - accuracy: 0.5041 - val_loss: 1.1900 - val_accuracy: 0.5286
# Epoch 10/50
# 197/197 [==============================] - 1s 5ms/step - loss: 1.1888 - accuracy: 0.5235 - val_loss: 1.1721 - val_accuracy: 0.5114
# Epoch 11/50
# 197/197 [==============================] - 1s 5ms/step - loss: 1.1520 - accuracy: 0.5572 - val_loss: 1.1303 - val_accuracy: 0.5829
# Epoch 12/50
# 197/197 [==============================] - 1s 5ms/step - loss: 1.1382 - accuracy: 0.5425 - val_loss: 1.1246 - val_accuracy: 0.5286
# Epoch 13/50
# 197/197 [==============================] - 1s 5ms/step - loss: 1.0697 - accuracy: 0.5793 - val_loss: 1.2014 - val_accuracy: 0.5114
# Epoch 14/50
# 197/197 [==============================] - 1s 5ms/step - loss: 1.1133 - accuracy: 0.5643 - val_loss: 1.0646 - val_accuracy: 0.5771
# Epoch 15/50
# 197/197 [==============================] - 1s 5ms/step - loss: 1.0564 - accuracy: 0.6124 - val_loss: 1.0751 - val_accuracy: 0.5629
# Epoch 16/50
# 197/197 [==============================] - 1s 5ms/step - loss: 0.9935 - accuracy: 0.6159 - val_loss: 1.0761 - val_accuracy: 0.5857
# Epoch 17/50
# 197/197 [==============================] - 1s 5ms/step - loss: 1.0190 - accuracy: 0.6078 - val_loss: 1.0549 - val_accuracy: 0.5886
# Epoch 18/50
# 197/197 [==============================] - 1s 5ms/step - loss: 1.0046 - accuracy: 0.6163 - val_loss: 1.0448 - val_accuracy: 0.6171
# Epoch 19/50
# 197/197 [==============================] - 1s 5ms/step - loss: 0.9609 - accuracy: 0.6337 - val_loss: 1.0458 - val_accuracy: 0.6029
# Epoch 20/50
# 197/197 [==============================] - 1s 5ms/step - loss: 0.9531 - accuracy: 0.6337 - val_loss: 0.9851 - val_accuracy: 0.6029
# Epoch 21/50
# 197/197 [==============================] - 1s 5ms/step - loss: 0.9420 - accuracy: 0.6377 - val_loss: 0.9651 - val_accuracy: 0.6229
# Epoch 22/50
# 197/197 [==============================] - 1s 5ms/step - loss: 0.9080 - accuracy: 0.6452 - val_loss: 0.9280 - val_accuracy: 0.6429
# Epoch 23/50
# 197/197 [==============================] - 1s 5ms/step - loss: 0.8845 - accuracy: 0.6618 - val_loss: 0.9548 - val_accuracy: 0.6400
# Epoch 24/50
# 197/197 [==============================] - 1s 5ms/step - loss: 0.8875 - accuracy: 0.6661 - val_loss: 0.9279 - val_accuracy: 0.6657
# Epoch 25/50
# 197/197 [==============================] - 1s 5ms/step - loss: 0.8595 - accuracy: 0.6792 - val_loss: 0.9052 - val_accuracy: 0.6600
# Epoch 26/50
# 197/197 [==============================] - 1s 5ms/step - loss: 0.8506 - accuracy: 0.6697 - val_loss: 0.8934 - val_accuracy: 0.6829
# Epoch 27/50
# 197/197 [==============================] - 1s 5ms/step - loss: 0.8498 - accuracy: 0.6765 - val_loss: 0.8745 - val_accuracy: 0.6743
# Epoch 28/50
# 197/197 [==============================] - 1s 5ms/step - loss: 0.7938 - accuracy: 0.6877 - val_loss: 0.8910 - val_accuracy: 0.6943
# Epoch 29/50
# 197/197 [==============================] - 1s 5ms/step - loss: 0.7941 - accuracy: 0.7062 - val_loss: 0.8921 - val_accuracy: 0.7029
# Epoch 30/50
# 197/197 [==============================] - 1s 6ms/step - loss: 0.7822 - accuracy: 0.7097 - val_loss: 0.8560 - val_accuracy: 0.7229
# Epoch 31/50
# 197/197 [==============================] - 1s 5ms/step - loss: 0.7780 - accuracy: 0.6946 - val_loss: 0.8135 - val_accuracy: 0.7257
# Epoch 32/50
# 197/197 [==============================] - 1s 5ms/step - loss: 0.7839 - accuracy: 0.6941 - val_loss: 0.8953 - val_accuracy: 0.6686
# Epoch 33/50
# 197/197 [==============================] - 1s 5ms/step - loss: 0.7373 - accuracy: 0.7312 - val_loss: 0.8867 - val_accuracy: 0.6743
# Epoch 34/50
# 197/197 [==============================] - 1s 5ms/step - loss: 0.7519 - accuracy: 0.7135 - val_loss: 0.7797 - val_accuracy: 0.7171
# Epoch 35/50
# 197/197 [==============================] - 1s 6ms/step - loss: 0.7487 - accuracy: 0.7202 - val_loss: 0.8334 - val_accuracy: 0.7029
# Epoch 36/50
# 197/197 [==============================] - 1s 6ms/step - loss: 0.7192 - accuracy: 0.7232 - val_loss: 0.7705 - val_accuracy: 0.7371
# Epoch 37/50
# 197/197 [==============================] - 1s 6ms/step - loss: 0.6905 - accuracy: 0.7473 - val_loss: 0.7838 - val_accuracy: 0.7400
# Epoch 38/50
# 197/197 [==============================] - 1s 5ms/step - loss: 0.7378 - accuracy: 0.7166 - val_loss: 0.8162 - val_accuracy: 0.7200
# Epoch 39/50
# 197/197 [==============================] - 1s 5ms/step - loss: 0.6804 - accuracy: 0.7425 - val_loss: 0.7880 - val_accuracy: 0.7400
# Epoch 40/50
# 197/197 [==============================] - 1s 5ms/step - loss: 0.6783 - accuracy: 0.7479 - val_loss: 0.8015 - val_accuracy: 0.7286
# Epoch 41/50
# 197/197 [==============================] - 1s 6ms/step - loss: 0.7093 - accuracy: 0.7323 - val_loss: 0.8042 - val_accuracy: 0.7171
# Epoch 42/50
# 197/197 [==============================] - 1s 5ms/step - loss: 0.7188 - accuracy: 0.7366 - val_loss: 0.7977 - val_accuracy: 0.7371
# Epoch 43/50
# 197/197 [==============================] - 1s 5ms/step - loss: 0.7193 - accuracy: 0.7415 - val_loss: 0.7810 - val_accuracy: 0.7371
# Epoch 44/50
# 197/197 [==============================] - 1s 5ms/step - loss: 0.6504 - accuracy: 0.7643 - val_loss: 0.7572 - val_accuracy: 0.7514
# Epoch 45/50
# 197/197 [==============================] - 1s 5ms/step - loss: 0.6464 - accuracy: 0.7527 - val_loss: 0.7483 - val_accuracy: 0.7657
# Epoch 46/50
# 197/197 [==============================] - 1s 5ms/step - loss: 0.6592 - accuracy: 0.7583 - val_loss: 0.7728 - val_accuracy: 0.7429
# Epoch 47/50
# 197/197 [==============================] - 1s 5ms/step - loss: 0.6351 - accuracy: 0.7669 - val_loss: 0.6852 - val_accuracy: 0.7657
# Epoch 48/50
# 197/197 [==============================] - 1s 5ms/step - loss: 0.6427 - accuracy: 0.7550 - val_loss: 0.7052 - val_accuracy: 0.7514
# Epoch 49/50
# 197/197 [==============================] - 1s 5ms/step - loss: 0.6178 - accuracy: 0.7689 - val_loss: 0.7399 - val_accuracy: 0.7571
# Epoch 50/50
# 197/197 [==============================] - 1s 5ms/step - loss: 0.6339 - accuracy: 0.7653 - val_loss: 0.7560 - val_accuracy: 0.7429

# %%
score = model.evaluate(x_train,y_train,verbose=0)
print('test loss = ',score[0])
print('accuracy = ',score[1])
# Out:
# test loss =  0.3978680968284607
# accuracy =  0.8898412585258484

# %%
score = model.evaluate(x_test,y_test,verbose=0)
print('test loss = ',score[0])
print('accuracy = ',score[1])
# Out:
# test loss =  0.755998969078064
# accuracy =  0.7428571581840515

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# #Predictions

# %%
y_pred = model.predict(x_test)

# %%
y_pred_classes = np.argmax(y_pred, axis = 1)

# %%
y_true = np.argmax(y_test, axis = 1)

# %%
cm = confusion_matrix(y_true, y_pred_classes)

# %%
sns.heatmap(cm,annot=True,fmt='g')

# %%
fig, ax = plt.subplots(figsize=(6,6))
sns.set(font_scale=1.6)
sns.heatmap(cm, annot=True, linewidths=.5, ax=ax)

# %%
incorr_fraction = 1 - np.diag(cm) / np.sum(cm, axis=1)
plt.bar(np.arange(7), incorr_fraction)
plt.xlabel('True Label')
plt.ylabel('Fraction of incorrect predictions')
# Out:
# Text(0, 0.5, 'Fraction of incorrect predictions')
